# %%
msg = "Hello World"
print(msg)
# Out:
# Hello World

# %%
msg = "Hello again"
print(msg)
# Out:
# Hello again

# %%
A=1
B=2
A+B
# Out:
# 3

# %%
A=1
B=2
A+B
# Out:
# 3

# %%
msg = "Hello again"
print(msg)
# Out:
# Hello again

# %%
A=1
B=2
A+B
# Out:
# 3
